# %%
import scda
import pprint
import logging
import os
import numpy as np
scda.configure_log()

# %%
survey_dir = os.path.normpath("/astro/opticslab1/SCDA/Scripts/AMPL/april_survey01_10bw/")
os.chdir(survey_dir)
os.listdir(".")
# Out:
# ['amplsrc',
#  'solutions',
#  'logs',
#  'slurmsh',
#  'april_survey01_10bw_kstlaurent_2016-04-26.csv',
#  'april_survey01_10bw_kstlaurent_2016-04-26.pkl',
#  'april_survey01_10bw_kstlaurent_2016-04-25.pkl',
#  'april_survey01_10bw_ntz_2016-04-21.pkl',
#  'april_survey01_10bw_kstlaurent_2016-04-26_ntzeval.csv',
#  'crontab_april_survey01_10bw_kstlaurent_2016-04-25',
#  'queuefill.log']

# %%
#os.listdir("./solutions/")

# %%
survey_archive_fname = "april_survey01_10bw_kstlaurent_2016-04-26.pkl"

# %%
survey_archive = scda.load_design_param_survey(survey_archive_fname)

# %%
survey_archive.eval_metrics(verbose=True)
# Out:
# Non-binary residuals, as a percentage of clear telescope aperture area: 15.96%
# Band-averaged Airy throughput: 9.25%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.44
# Non-binary residuals, as a percentage of clear telescope aperture area: 0.28%
# Band-averaged Airy throughput: 0.00%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.72
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 16.64%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.20
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 17.65%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.17
# Non-binary residuals, as a percentage of clear telescope aperture area: 18.57%
# Band-averaged Airy throughput: 9.37%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.40
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 13.90%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.20
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 14.97%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.17
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 15.69%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.11
# Non-binary residuals, as a percentage of clear telescope aperture area: 20.55%
# Band-averaged Airy throughput: 8.67%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.34
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 12.12%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.17
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 12.93%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.11
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 13.92%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.09
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.50%
# Band-averaged Airy throughput: 40.91%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.39
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 16.00%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.29
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 16.64%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.20
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 17.65%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.17
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.56%
# Band-averaged Airy throughput: 36.62%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.00%
# Band-averaged Airy throughput: 0.28%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.76
# Non-binary residuals, as a percentage of clear telescope aperture area: 1.83%
# Band-averaged Airy throughput: 0.05%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.70
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 15.69%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.11
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.60%
# Band-averaged Airy throughput: 27.10%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.27
# Non-binary residuals, as a percentage of clear telescope aperture area: 51.18%
# Band-averaged Airy throughput: 12.12%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.17
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.17%
# Band-averaged Airy throughput: 0.16%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.53
# Non-binary residuals, as a percentage of clear telescope aperture area: 1.95%
# Band-averaged Airy throughput: 0.07%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.61
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.20%
# Band-averaged Airy throughput: 37.11%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.41
# Non-binary residuals, as a percentage of clear telescope aperture area: 9.58%
# Band-averaged Airy throughput: 22.85%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.47
# Non-binary residuals, as a percentage of clear telescope aperture area: 9.54%
# Band-averaged Airy throughput: 12.73%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 2.02
# Non-binary residuals, as a percentage of clear telescope aperture area: 14.77%
# Band-averaged Airy throughput: 7.10%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.97
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.04%
# Band-averaged Airy throughput: 35.06%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 8.90%
# Band-averaged Airy throughput: 19.76%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.38
# Non-binary residuals, as a percentage of clear telescope aperture area: 8.53%
# Band-averaged Airy throughput: 9.99%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.91
# Non-binary residuals, as a percentage of clear telescope aperture area: 13.22%
# Band-averaged Airy throughput: 8.26%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.97
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.35%
# Band-averaged Airy throughput: 31.36%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.23
# Non-binary residuals, as a percentage of clear telescope aperture area: 14.26%
# Band-averaged Airy throughput: 15.08%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.30
# Non-binary residuals, as a percentage of clear telescope aperture area: 0.84%
# Band-averaged Airy throughput: 6.74%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.78
# Non-binary residuals, as a percentage of clear telescope aperture area: 10.87%
# Band-averaged Airy throughput: 6.03%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.85
# Non-binary residuals, as a percentage of clear telescope aperture area: 17.57%
# Band-averaged Airy throughput: 11.00%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.44
# Non-binary residuals, as a percentage of clear telescope aperture area: 12.90%
# Band-averaged Airy throughput: 4.94%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.42
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.53%
# Band-averaged Airy throughput: 1.53%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.40
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.52%
# Band-averaged Airy throughput: 0.24%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.42
# Non-binary residuals, as a percentage of clear telescope aperture area: 2.78%
# Band-averaged Airy throughput: 10.51%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.39
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.48%
# Band-averaged Airy throughput: 6.27%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.39
# Non-binary residuals, as a percentage of clear telescope aperture area: 7.83%
# Band-averaged Airy throughput: 3.11%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.40
# Non-binary residuals, as a percentage of clear telescope aperture area: 6.60%
# Band-averaged Airy throughput: 1.69%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.43
# Non-binary residuals, as a percentage of clear telescope aperture area: 16.01%
# Band-averaged Airy throughput: 9.84%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.34
# Non-binary residuals, as a percentage of clear telescope aperture area: 11.50%
# Band-averaged Airy throughput: 7.37%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 1.66%
# Band-averaged Airy throughput: 5.11%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 1.43%
# Band-averaged Airy throughput: 3.64%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 2.91%
# Band-averaged Airy throughput: 41.34%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.36
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.20%
# Band-averaged Airy throughput: 42.49%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.46%
# Band-averaged Airy throughput: 42.71%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.11%
# Band-averaged Airy throughput: 41.84%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.13%
# Band-averaged Airy throughput: 36.86%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.31
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.08%
# Band-averaged Airy throughput: 39.81%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.30
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.51%
# Band-averaged Airy throughput: 39.93%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.29
# Non-binary residuals, as a percentage of clear telescope aperture area: 9.05%
# Band-averaged Airy throughput: 37.65%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.28
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.40%
# Band-averaged Airy throughput: 28.12%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.25
# Non-binary residuals, as a percentage of clear telescope aperture area: 6.51%
# Band-averaged Airy throughput: 31.66%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.22
# Non-binary residuals, as a percentage of clear telescope aperture area: 7.15%
# Band-averaged Airy throughput: 30.14%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.22
# Non-binary residuals, as a percentage of clear telescope aperture area: 2.03%
# Band-averaged Airy throughput: 27.53%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.20
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.38%
# Band-averaged Airy throughput: 41.09%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.38
# Non-binary residuals, as a percentage of clear telescope aperture area: 6.67%
# Band-averaged Airy throughput: 41.08%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.30%
# Band-averaged Airy throughput: 41.66%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.30
# Non-binary residuals, as a percentage of clear telescope aperture area: 2.82%
# Band-averaged Airy throughput: 42.09%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.26
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.05%
# Band-averaged Airy throughput: 37.46%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.23%
# Band-averaged Airy throughput: 40.35%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.29
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.29%
# Band-averaged Airy throughput: 41.11%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.22
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.33%
# Band-averaged Airy throughput: 41.79%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.19
# Non-binary residuals, as a percentage of clear telescope aperture area: 2.31%
# Band-averaged Airy throughput: 32.73%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.26
# Non-binary residuals, as a percentage of clear telescope aperture area: 10.79%
# Band-averaged Airy throughput: 34.45%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.20
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.38%
# Band-averaged Airy throughput: 36.79%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.17
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.84%
# Band-averaged Airy throughput: 37.80%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.17
# Non-binary residuals, as a percentage of clear telescope aperture area: 17.83%
# Band-averaged Airy throughput: 11.72%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.42
# Non-binary residuals, as a percentage of clear telescope aperture area: 11.21%
# Band-averaged Airy throughput: 4.19%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.38
# Non-binary residuals, as a percentage of clear telescope aperture area: 1.64%
# Band-averaged Airy throughput: 0.77%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.34
# Non-binary residuals, as a percentage of clear telescope aperture area: 52.08%
# Band-averaged Airy throughput: 18.51%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.17
# Non-binary residuals, as a percentage of clear telescope aperture area: 12.81%
# Band-averaged Airy throughput: 11.43%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.37
# Non-binary residuals, as a percentage of clear telescope aperture area: 6.17%
# Band-averaged Airy throughput: 5.21%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.34
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.83%
# Band-averaged Airy throughput: 1.87%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.38
# Non-binary residuals, as a percentage of clear telescope aperture area: 0.67%
# Band-averaged Airy throughput: 0.71%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.42
# Non-binary residuals, as a percentage of clear telescope aperture area: 17.53%
# Band-averaged Airy throughput: 10.56%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.20%
# Band-averaged Airy throughput: 7.35%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.31
# Non-binary residuals, as a percentage of clear telescope aperture area: 1.52%
# Band-averaged Airy throughput: 4.28%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.31
# Non-binary residuals, as a percentage of clear telescope aperture area: 6.17%
# Band-averaged Airy throughput: 2.77%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 2.89%
# Band-averaged Airy throughput: 40.16%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.42
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.84%
# Band-averaged Airy throughput: 42.43%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.30%
# Band-averaged Airy throughput: 43.97%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.31
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.95%
# Band-averaged Airy throughput: 43.21%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.10%
# Band-averaged Airy throughput: 36.11%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.36
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.23%
# Band-averaged Airy throughput: 39.87%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.31
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.27%
# Band-averaged Airy throughput: 41.52%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.29
# Non-binary residuals, as a percentage of clear telescope aperture area: 8.48%
# Band-averaged Airy throughput: 39.36%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.29
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.51%
# Band-averaged Airy throughput: 27.03%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.28
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.32%
# Band-averaged Airy throughput: 31.55%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.23
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.95%
# Band-averaged Airy throughput: 31.68%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.20
# Non-binary residuals, as a percentage of clear telescope aperture area: 8.62%
# Band-averaged Airy throughput: 28.76%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.20
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.28%
# Band-averaged Airy throughput: 40.82%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.40
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.36%
# Band-averaged Airy throughput: 40.74%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.30
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.17%
# Band-averaged Airy throughput: 40.07%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.23
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.24%
# Band-averaged Airy throughput: 40.27%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.19
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.96%
# Band-averaged Airy throughput: 37.74%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.35
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.79%
# Band-averaged Airy throughput: 41.31%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.30
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.76%
# Band-averaged Airy throughput: 41.37%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.22
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.78%
# Band-averaged Airy throughput: 40.39%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.19
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.73%
# Band-averaged Airy throughput: 32.84%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.31
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.77%
# Band-averaged Airy throughput: 35.06%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.20
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.25%
# Band-averaged Airy throughput: 37.79%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.19
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.94%
# Band-averaged Airy throughput: 36.12%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.17
# Non-binary residuals, as a percentage of clear telescope aperture area: 18.72%
# Band-averaged Airy throughput: 11.26%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.44
# Non-binary residuals, as a percentage of clear telescope aperture area: 11.32%
# Band-averaged Airy throughput: 5.05%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.42
# Non-binary residuals, as a percentage of clear telescope aperture area: 6.32%
# Band-averaged Airy throughput: 1.43%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.40
# Non-binary residuals, as a percentage of clear telescope aperture area: 1.39%
# Band-averaged Airy throughput: 0.25%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.42
# Non-binary residuals, as a percentage of clear telescope aperture area: 13.67%
# Band-averaged Airy throughput: 10.94%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.39
# Non-binary residuals, as a percentage of clear telescope aperture area: 10.97%
# Band-averaged Airy throughput: 6.32%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.39
# Non-binary residuals, as a percentage of clear telescope aperture area: 6.15%
# Band-averaged Airy throughput: 1.60%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.44
# Non-binary residuals, as a percentage of clear telescope aperture area: 12.83%
# Band-averaged Airy throughput: 5.29%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 9.06%
# Band-averaged Airy throughput: 3.80%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.35%
# Band-averaged Airy throughput: 41.01%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.41
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.63%
# Band-averaged Airy throughput: 36.79%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.36
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.03%
# Band-averaged Airy throughput: 37.58%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.32
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.27%
# Band-averaged Airy throughput: 40.25%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.29
# Non-binary residuals, as a percentage of clear telescope aperture area: 9.89%
# Band-averaged Airy throughput: 37.80%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.30
# Non-binary residuals, as a percentage of clear telescope aperture area: 8.97%
# Band-averaged Airy throughput: 25.33%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.29
# Non-binary residuals, as a percentage of clear telescope aperture area: 9.70%
# Band-averaged Airy throughput: 25.16%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.25
# Non-binary residuals, as a percentage of clear telescope aperture area: 14.56%
# Band-averaged Airy throughput: 22.62%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.19
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.36%
# Band-averaged Airy throughput: 41.05%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.40
# Non-binary residuals, as a percentage of clear telescope aperture area: 2.03%
# Band-averaged Airy throughput: 40.78%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.34
# Non-binary residuals, as a percentage of clear telescope aperture area: 4.91%
# Band-averaged Airy throughput: 40.61%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.30
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.72%
# Band-averaged Airy throughput: 40.76%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.24
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.88%
# Band-averaged Airy throughput: 37.51%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.35
# Non-binary residuals, as a percentage of clear telescope aperture area: 3.34%
# Band-averaged Airy throughput: 38.26%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.31
# Non-binary residuals, as a percentage of clear telescope aperture area: 5.19%
# Band-averaged Airy throughput: 40.67%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.22
# Non-binary residuals, as a percentage of clear telescope aperture area: 2.59%
# Band-averaged Airy throughput: 31.42%
# Band-averaged FWHM PSF area / (lambda0/D)^2: 1.27

# %%
survey_archive.write_spreadsheet(csv_fname="april_survey01_10bw_kstlaurent_2016-04-26_ntzeval.csv")
# Out:
# INFO:root:Wrote design survey spreadsheet to ./april_survey01_10bw_kstlaurent_2016-04-26_ntzeval.csv
